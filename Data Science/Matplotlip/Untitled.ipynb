# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4],[1,4,9,0], color ="green", linestyle ="dashdot", label="dashdot")
plt.plot([2,3,4,5], color ="red", linestyle ="dashdot", label="dashed")
plt.legend()
plt.show()
